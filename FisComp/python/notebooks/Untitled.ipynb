# %%
import numpy as np
import matplotlib.pyplot as plt

t  = np.arange(0, 10.5, 0.5)
tau = 5
tVel = 25
iPos = 200

def vel(tVel, t, tau):
    vel = -tVel * (1-np.exp(-t/tau))
    return vel

def acc(tVel, t, tau):
    acc = -(tVel*np.exp(-t/tau)/(tau))
    return acc
            
def positionEq(t, tVel, tau):
    position = -tVel*(tau*np.exp(-t/tau)+t)
    return position

fVel = vel(tVel, t, tau)
fAcc = (tVel, t, tau)
fPos = iPos + positionEq(t, tVel, tau)

plt.plot(nojkobn
